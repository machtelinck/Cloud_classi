# %% [markdown]
# <a href="https://colab.research.google.com/github/machtelinck/Cloud_classi/blob/main/Copie_de_Cloud_classi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cloud Classification 
# importer le dataset 
# geler les couches 
# copier les modèle précedent 
# voir les prédictions 
# voir option pour entrainement a distance

# %%
# !pip install roboflow
# !pip install ultralytics
from roboflow import Roboflow
rf = Roboflow(api_key="mettre_api_key")
project = rf.workspace("simplon-xajv7").project("cloud_classification-cjuda")
dataset = project.version(2).download("yolov8")
#snippet donné par roboflow#
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 2.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 5.6 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=fc6adbdd977c73aed68dd1c03539cbf3f0b7863c34684c5d9bb4d4e419971ca9
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 160MB/s]
# Ultralytics YOLOv8.0.72 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pip install ultralytics==8.0.20
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 KB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.72
#     Uninstalling ultralytics-8.0.72:
#       Successfully uninstalled ultralytics-8.0.72
# ...

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"runs/detect/train/")
# Out:
# Dependency ultralytics<=8.0.20 is required but found version=8.0.72, to fix: `pip install ultralytics<=8.0.20`
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.
